# %% [markdown]
# <a href="https://colab.research.google.com/github/psbhara/ADA3/blob/main/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bellman_ford(edges, vertices, source):

    dist = {v: float('inf') for v in vertices}
    dist[source] = 0


    for _ in range(len(vertices) - 1):
        for u, v, w in edges:
            if dist[u] != float('inf') and dist[u] + w < dist[v]:
                dist[v] = dist[u] + w

    for u, v, w in edges:
        if dist[u] + w < dist[v]:
            print("Graph contains a negative weight cycle!")
            return None

    return dist

# %%
vertices = ['A', 'B', 'C', 'D']

edges = [
    ('A', 'B', 4),
    ('A', 'C', 5),
    ('B', 'C', -2),
    ('C', 'D', 3),
    ('B', 'D', 6)
]

source = 'A'

# %%
print(bellman_ford(edges, vertices, source))
# Out:
# {'A': 0, 'B': 4, 'C': 2, 'D': 5}
